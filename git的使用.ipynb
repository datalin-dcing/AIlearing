# %% [markdown]
# 教程网页;https://zhuanlan.zhihu.com/p/690957659

# %% [markdown]
# 1. 安装git的软件包
# 2. 配置git的用户名和邮箱
# 3. 安装git 的时候就已经安装了ssh，利用ssh生成密钥和公钥
#     ssh-keygen -t rsa
# 4. 在github上面登录自己的账号，setting 到获取创建密钥的页面，创建new_ssh，将公钥复制进去，保存
# 5. 本地测试是否能连接远程github
#     ssh -T git@github.com
# s
# 6. 可以在git页面创建自己的仓库，也可以在本地git init 初始化自己的文件，remote 到自己的远程仓库
#     git init
#     git add YOLOV3
#     git commit -m "yolov3课件"
#     git remote add origin https://github.com/datalin-dcing/AIcourse.git
#     git push -u origin master

# %%
#家里的电脑
